# %% [markdown]
# <a href="https://colab.research.google.com/github/talhabhati/Anomaly-detection-using-pytorch/blob/main/tensors_shape.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Tensors shape
import torch
print(torch.__version__)
# Out:
# 2.9.0+cpu

# %%
x=torch.tensor([[1,2,3],[7,8,9]])
x
# Out:
# tensor([[1, 2, 3],
#         [7, 8, 9]])

# %%
#to check shape of tensor
x.shape
# Out:
# torch.Size([2, 3])

# %%
#to copy shape like a tensor
torch.empty_like(x)
# Out:
# tensor([[3180222411935070754, 4189017755886035488, 7308535291872901920],
#         [4189017755886051700, 8027140907415206688, 7018332503360695925]])

# %%
torch.zeros_like(x)
# Out:
# tensor([[0, 0, 0],
#         [0, 0, 0]])

# %%
torch.ones_like(x)
# Out:
# tensor([[1, 1, 1],
#         [1, 1, 1]])

# %%
torch.rand_like(x)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# /tmp/ipython-input-964596337.py in <cell line: 0>()
# ----> 1 torch.rand_like(x)
#
# NotImplementedError: "check_uniform_bounds" not implemented for 'Long'
